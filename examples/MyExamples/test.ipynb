# %%
from neuralogic.nn import get_evaluator
from neuralogic.core import Template, R, V, C, Settings, Transformation, Combination, Aggregation
from neuralogic.core.constructs.function.tree import FunctionContainer
from neuralogic.core.settings import Settings
from neuralogic.dataset import Dataset
from neuralogic.optim import SGD

F = FunctionContainer()
train_dataset = Dataset()
template = Template()


train_dataset.add_example([R.b[3], R.c[5], R.d[1]])
train_dataset.add_queries([R.a[8]])

# %%
template += (R.a <= (x:=R.b, y:=R.c, z:=R.d)) >> F.avg(F.identity(x + y * z))
#F.custom(x + y * z)

template.draw()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 template += (R.a <= (x:=R.b, y:=R.c, z:=R.d)) >> F.avg(F.identity(x + y * z))
#       3 template.draw()
#
# File ~\Plocha\BAK\PyNeuraLogicFork\neuralogic\core\constructs\rule.py:138, in Rule.__rshift__(self, tree)
#     135     return self.__or__(tree)
#     137 elif isinstance(tree, FunctionalTree):
# --> 138     metadata = tree.create_metadata()
#     139     return self.__or__(metadata)
#
# File ~\Plocha\BAK\PyNeuraLogicFork\neuralogic\core\constructs\function\tree.py:50, in FunctionalTree.create_metadata(self)
#      48 operations = self.note_operations()
#      49 operations.reverse()
# ---> 50 metadata = self.process_operations(operations)
#      51 return metadata
#
# File ~\Plocha\BAK\PyNeuraLogicFork\neuralogic\core\constructs\function\tree.py:75, in FunctionalTree.process_operations(self, operations)
#      73         metadata.append(op)
#      74     elif last_comb != op:
# ---> 75         raise Exception("Combination types must be the same.")
#      76     no_comb += 1
#      77 elif isinstance(op, Transformation):
#
# Exception: Combination types must be the same.

# %%
settings = Settings(optimizer=SGD(), epochs=1)
neuralogic_evaluator = get_evaluator(template, settings)
build_dataset = neuralogic_evaluator.build_dataset(train_dataset)

for _ in neuralogic_evaluator.train(train_dataset):
    pass

build_dataset[0].draw()
